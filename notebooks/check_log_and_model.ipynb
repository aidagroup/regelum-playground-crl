# %%
import os

if 'main_dir' in globals():
    os.chdir(main_dir)

import pandas as pd
from utils.load_config import load_exp_config, get_value_from_fields, get_df_historical_data
from utils.load_data import (
    get_df_from_datetime_range
    )
import numpy as np

# %matplotlib inline

if os.getcwd().endswith("notebooks"):
    main_dir = os.getcwd()
    os.chdir("..")

# %%
os.getuid()
# Out:
# 1000

# %%
DECAY_RATE = 1

start_datetime_str = "2024-11-04 15-18-27"
end_datetime_str = "2024-11-05 08-00-00"

# end_datetime_str = start_datetime_str = "2024-11-04 14-38-04"
# end_datetime_str = start_datetime_str = "2024-10-31 13-46-21"
# end_datetime_str = start_datetime_str = "2024-11-06 11-00-44" # Error of unchanged observation
# end_datetime_str = start_datetime_str = "2024-11-06 12-08-58"

# contain large buffer and reset buffer [true, false]
start_datetime_str = "2024-11-06 12-08-58"
end_datetime_str = "2024-11-06 13-27-35"

# contain large buffer and reset buffer [true, false] with bugfix on robot pursuit
start_datetime_str = "2024-11-07 08-38-32"
end_datetime_str = "2024-11-07 10-41-32"

# end_datetime_str = start_datetime_str = "2024-11-07 11-31-51"
end_datetime_str = start_datetime_str = "2024-11-09 14-13-27"

# Full run at server
start_datetime_str = "2024-11-07 14-35-44"
end_datetime_str = "2024-11-08 04-58-17"

# Test
end_datetime_str = start_datetime_str = "2024-11-08 21-30-23"
end_datetime_str = start_datetime_str = "2024-11-10 22-47-07"
end_datetime_str = start_datetime_str = "2024-11-11 07-38-36"
# end_datetime_str = start_datetime_str = "2024-11-09 20-42-20"


# end_datetime_str = start_datetime_str = "2024-11-08 21-30-23"

# end_datetime_str = start_datetime_str = "2024-11-10 14-18-31"
# end_datetime_str = start_datetime_str = "2024-11-10 16-46-24"


# Full SAC run at server
# start_datetime_str = "2024-11-08 22-32-12"
# end_datetime_str = "2024-11-09 06-05-21"

# SAC with Pushing Object
end_datetime_str = start_datetime_str = "2024-11-11 09-14-40"
end_datetime_str = start_datetime_str = "2024-11-11 11-23-51"

# SAC Line Following on Server
end_datetime_str = start_datetime_str = "2024-11-11 11-51-46"
end_datetime_str = start_datetime_str = "2024-11-11 13-44-04"
end_datetime_str = start_datetime_str = "2024-11-11 14-26-45"

end_datetime_str = start_datetime_str = "2024-11-09 22-07-25"

# SAC Pushing Object on PC
# end_datetime_str = start_datetime_str = "2024-11-11 15-25-33"

df = get_df_from_datetime_range(start_datetime_str, 
                                end_datetime_str, 
                                decay_rate=DECAY_RATE,
                                max_iter=np.inf,
                                validity_check=False,
                                reload=True
                                )

# end_datetime_str = start_datetime_str = "2024-11-11 09-14-40"
# df_2 = get_df_from_datetime_range(start_datetime_str, 
#                                 end_datetime_str, 
#                                 decay_rate=DECAY_RATE,
#                                 max_iter=np.inf,
#                                 validity_check=False,
#                                 reload=False
#                                 )

# df = pd.concat([df, df_2])

df.head()
# Out:
# Load path: /home/tcc/huyhoang/irlc_2025/regelum-playground-iclr/regelum_data/outputs/2024-11-09/22-07-25
#     time  running_objective current_value  current_undiscounted_value  \
# 0  0.000           0.489796          None                    0.489796
# 1  0.000           0.081633          None                    0.571429
# 2  0.165           0.000000          None                    0.571429
# 3  0.330           0.040816          None                    0.612245
# 4  0.495           0.000000          None                    0.612245
#
#    episode_id  iteration_id   task_name  step_id  phase  exploration  ...  \
# 0           1             1  circle_red        0  train         True  ...
# 1           1             1  circle_red        1  train         True  ...
# 2           1             1  circle_red        2  train         True  ...
# 3           1             1  circle_red        3  train         True  ...
# 4           1             1  circle_red        4  train         True  ...
#
#    Image pixel 293  Image pixel 294  Image pixel 295  Image pixel 296  \
# 0              0.0         0.466667              0.0              0.0
# 1              0.0         0.466667              0.0              0.0
# 2              0.0         0.466667              0.0              0.0
# 3              0.0         0.462745              0.0              0.0
# 4              0.0         0.462745              0.0              0.0
#
#    Image pixel 297  Image pixel 298  Image pixel 299  \
# 0         0.466667              0.0              0.0
# 1         0.466667              0.0              0.0
# 2         0.462745              0.0              0.0
# 3         0.458824              0.0              0.0
# 4         0.462745              0.0              0.0
#
#                                        absolute_path  \
# 0  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 1  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 2  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 3  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 4  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#
#                                           exp_config  \
# 0  {'policy': {'_target_': 'src.policy.PendulumPo...
# 1  {'policy': {'_target_': 'src.policy.PendulumPo...
# 2  {'policy': {'_target_': 'src.policy.PendulumPo...
# 3  {'policy': {'_target_': 'src.policy.PendulumPo...
# 4  {'policy': {'_target_': 'src.policy.PendulumPo...
#
#                                      experiment_path
# 0  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 1  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 2  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 3  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 4  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#
# [5 rows x 315 columns]

# %%
exp_config = df.exp_config.values[0]
df = df.reindex()
def extract_columns(row):
    scenario = row.exp_config["scenario"]["_target_"].split(".")[-1]
    is_reset_buffer = row.exp_config["scenario"]["reset_rb_each_task"]
    buffer_size = row.exp_config["scenario"]["buffer_size"]
    learning_starts = row.exp_config["scenario"]["learning_starts"]
    controller = "SAC" if "sac" in scenario.lower() else "TD3"
    category = scenario[:scenario.find(controller)]
    return category, controller, is_reset_buffer, buffer_size, learning_starts
    
    # return pd.Series(data=[category, controller, is_reset_buffer, buffer_size], 
    #                  index=["category", "controller", "is_reset_buffer", "buffer_size"])

tmp = df.apply(extract_columns, axis=1, result_type='expand')
# tmp = df.exp_config.apply(extract_columns)
tmp.columns = ["category", "controller", "is_reset_buffer", "buffer_size", "learning_starts"]
df = pd.concat([df, tmp], axis=1)

# %%
[c for c in df.columns if "pos" in c]
# Out:
# []

# %%
pd.Series(tmp.iloc[0], index=["category", "controller", "is_reset_buffer", "buffer_size"])
# Out:
# category           LineFollowing
# controller                   SAC
# is_reset_buffer
# buffer_size                16000
# Name: 0, dtype: object

# %%
############################### Robot Pursuit is misisng ###############################
# group_df = df.groupby(["controller", "category", "task_name", "is_reset_buffer"]).last()
group_df = df.groupby(["controller", "category", "buffer_size"]).last()
group_df
# Out:
#                                       time  running_objective current_value  \
# controller category      buffer_size
# SAC        LineFollowing 16000        4.62           0.979592          None
#
#                                       current_undiscounted_value  episode_id  \
# controller category      buffer_size
# SAC        LineFollowing 16000                         25.632653           1
#
#                                       iteration_id      task_name  step_id  \
# controller category      buffer_size
# SAC        LineFollowing 16000                 731  circle_yellow      119
#
#                                      phase  exploration  ...  Image pixel 295  \
# controller category      buffer_size                     ...
# SAC        LineFollowing 16000        eval        False  ...              0.0
#
#                                       Image pixel 296  Image pixel 297  \
# controller category      buffer_size
# SAC        LineFollowing 16000                    0.0              0.0
#
#                                       Image pixel 298  Image pixel 299  \
# controller category      buffer_size
# SAC        LineFollowing 16000                    0.0              0.0
#
#                                                                           absolute_path  \
# controller category      buffer_size
# SAC        LineFollowing 16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#
#                                                                              exp_config  \
# controller category      buffer_size
# SAC        LineFollowing 16000        {'policy': {'_target_': 'src.policy.PendulumPo...
#
#                                                                         experiment_path  \
# controller category      buffer_size
# SAC        LineFollowing 16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#
#                                       is_reset_buffer  learning_starts
# controller category      buffer_size
# SAC        LineFollowing 16000                                     400
#
# [1 rows x 317 columns]

# %%
group_df.index.names, group_df.index[0]
# Out:
# (FrozenList(['controller', 'category', 'buffer_size']),
#  ('SAC', 'LineFollowing', 16000))

# %%
"\t".join([f"{a}:{b}" for a, b in list(zip(group_df.index.names, group_df.index[0]))])
# list(zip(group_df.index.names, group_df.index[0]))
group_df.index
# Out:
# MultiIndex([('SAC', 'LineFollowing', 16000)],
#            names=['controller', 'category', 'buffer_size'])

# %%
df = df.reset_index().set_index(group_df.index.names)
tmp_df = df.loc[group_df.index[0]]

# %%
from matplotlib import rc
# rc('font',**{'family':'sans-serif','sans-serif':['Helvelica']})
# for Palatino and other serif fonts use:
# rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=False)

# %%
import matplotlib
print(matplotlib.matplotlib_fname())
matplotlib.__version__
# Out:
# /home/tcc/huyhoang/irlc_2025/regelum-playground-iclr/venv/lib/python3.10/site-packages/matplotlib/mpl-data/matplotlibrc
# '3.9.2'

# %%
import matplotlib.pyplot as plt
# import matplotlib
# %matplotlib inline

def plot_learning_curve(index, index_names, df, title="Learning curve"):
    fig, ax = plt.subplots(figsize=(10,3))

    df = df.reset_index().set_index(index_names)
    tmp_df = df.loc[index]

    # Filter exploration actions
    tmp_df = tmp_df.loc[:, ["iteration_id", "step_id", "task_name", "current_undiscounted_value", "learning_starts", "phase"]]
    tmp_df = tmp_df[np.invert(np.logical_and(tmp_df.phase == "train", tmp_df.step_id <= tmp_df.learning_starts))]
    tmp_group_df = tmp_df.groupby("iteration_id")

    tmp_group_df = tmp_group_df.aggregate({
        "current_undiscounted_value": "last", 
        "task_name": "last",
        "step_id": "last"
        })
    
    # Re-assign index for ploting
    tmp_group_df = tmp_group_df.reset_index()
    tmp_group_df.iteration_id = tmp_group_df.reset_index().index
    tmp_group_df = tmp_group_df.set_index("iteration_id")

    tmp_group_df.plot(y="current_undiscounted_value", ax=ax)

    colors = ["red", "blue", "green", "yellow"]
    for t in tmp_group_df.task_name.unique():
        for c in colors:
            if c in t.lower():
                break

        tmp = tmp_group_df.reset_index().set_index("task_name").loc[t]
        ax.axvspan(tmp.iteration_id.values[0], tmp.iteration_id.values[-1], alpha=0.7, color=c)

    ax.set_xlabel('Episode')
    ax.set_ylabel('Accumulated reward per episode')
    ax.set_title(
        f'{title}\n' + 
        "   ".join([f"{a}: {b}" for a, b in list(zip(index_names, index))])
    )
    legend = ax.legend()
    legend.remove()


for id in group_df.index:
    plot_learning_curve(id, group_df.index.names, df)
    
# plot_learning_curve(group_df.index[1], group_df.index.names, df)
# plot_learning_curve(('SAC', 'LineFollowing', True), group_df.index.names, df)
# plot_learning_curve(('TD3', 'LineFollowing', False), group_df.index.names, df)
# plt.show()

# %%
df = df.reset_index()
df[df.iteration_id==1]
# Out:
#    controller       category  buffer_size  index   time  running_objective  \
# 0         SAC  LineFollowing        16000      0  0.000           0.489796
# 1         SAC  LineFollowing        16000      1  0.000           0.081633
# 2         SAC  LineFollowing        16000      2  0.165           0.000000
# 3         SAC  LineFollowing        16000      3  0.330           0.040816
# 4         SAC  LineFollowing        16000      4  0.495           0.000000
# 5         SAC  LineFollowing        16000      5  0.660           0.000000
# 6         SAC  LineFollowing        16000      6  0.825           0.000000
# 7         SAC  LineFollowing        16000      7  0.990           0.000000
# 8         SAC  LineFollowing        16000      8  1.155           0.000000
# 9         SAC  LineFollowing        16000      9  1.320           0.000000
# 10        SAC  LineFollowing        16000     10  1.485           0.000000
# 11        SAC  LineFollowing        16000     11  1.650           0.000000
# 12        SAC  LineFollowing        16000     12  1.815           0.000000
# 13        SAC  LineFollowing        16000     13  1.980           0.000000
# 14        SAC  LineFollowing        16000     14  2.145           0.000000
# 15        SAC  LineFollowing        16000     15  2.310           0.000000
# 16        SAC  LineFollowing        16000     16  2.475           0.000000
# 17        SAC  LineFollowing        16000     17  2.640           0.000000
# 18        SAC  LineFollowing        16000     18  2.805           0.000000
# 19        SAC  LineFollowing        16000     19  2.970           0.000000
# 20        SAC  LineFollowing        16000     20  3.135           0.000000
# 21        SAC  LineFollowing        16000     21  3.300           0.000000
# 22        SAC  LineFollowing        16000     22  3.465           0.000000
# 23        SAC  LineFollowing        16000     23  3.630           0.000000
# 24        SAC  LineFollowing        16000     24  3.795           0.000000
# 25        SAC  LineFollowing        16000     25  3.960           0.040816
# 26        SAC  LineFollowing        16000     26  4.125           0.000000
# 27        SAC  LineFollowing        16000     27  4.290           0.000000
# 28        SAC  LineFollowing        16000     28  4.455           0.000000
# 29        SAC  LineFollowing        16000     29  4.620           0.000000
#
#    current_value  current_undiscounted_value  episode_id  iteration_id  ...  \
# 0           None                    0.489796           1             1  ...
# 1           None                    0.571429           1             1  ...
# 2           None                    0.571429           1             1  ...
# 3           None                    0.612245           1             1  ...
# 4           None                    0.612245           1             1  ...
# 5           None                    0.612245           1             1  ...
# 6           None                    0.612245           1             1  ...
# 7           None                    0.612245           1             1  ...
# 8           None                    0.612245           1             1  ...
# 9           None                    0.612245           1             1  ...
# 10          None                    0.612245           1             1  ...
# 11          None                    0.612245           1             1  ...
# 12          None                    0.612245           1             1  ...
# 13          None                    0.612245           1             1  ...
# 14          None                    0.612245           1             1  ...
# 15          None                    0.612245           1             1  ...
# 16          None                    0.612245           1             1  ...
# 17          None                    0.612245           1             1  ...
# 18          None                    0.612245           1             1  ...
# 19          None                    0.612245           1             1  ...
# 20          None                    0.612245           1             1  ...
# 21          None                    0.612245           1             1  ...
# 22          None                    0.612245           1             1  ...
# 23          None                    0.612245           1             1  ...
# 24          None                    0.612245           1             1  ...
# 25          None                    0.653061           1             1  ...
# 26          None                    0.653061           1             1  ...
# 27          None                    0.653061           1             1  ...
# 28          None                    0.653061           1             1  ...
# 29          None                    0.653061           1             1  ...
#
#    Image pixel 295  Image pixel 296 Image pixel 297  Image pixel 298  \
# 0         0.000000         0.000000        0.466667         0.000000
# 1         0.000000         0.000000        0.466667         0.000000
# 2         0.000000         0.000000        0.462745         0.000000
# 3         0.000000         0.000000        0.458824         0.000000
# 4         0.000000         0.000000        0.462745         0.000000
# 5         0.000000         0.000000        0.458824         0.000000
# 6         0.000000         0.000000        0.458824         0.000000
# 7         0.000000         0.000000        0.458824         0.000000
# 8         0.000000         0.000000        0.454902         0.000000
# 9         0.000000         0.000000        0.454902         0.000000
# 10        0.000000         0.000000        0.454902         0.000000
# 11        0.000000         0.000000        0.450980         0.000000
# 12        0.000000         0.000000        0.450980         0.000000
# 13        0.000000         0.000000        0.447059         0.000000
# 14        0.000000         0.000000        0.450980         0.000000
# 15        0.000000         0.000000        0.450980         0.000000
# 16        0.000000         0.000000        0.447059         0.000000
# 17        0.000000         0.000000        0.450980         0.000000
# 18        0.000000         0.000000        0.447059         0.000000
# 19        0.000000         0.000000        0.450980         0.000000
# 20        0.000000         0.000000        0.447059         0.000000
# 21        0.000000         0.000000        0.443137         0.000000
# 22        0.000000         0.000000        0.443137         0.000000
# 23        0.003922         0.003922        0.439216         0.003922
# 24        0.003922         0.003922        0.439216         0.003922
# 25        0.000000         0.000000        0.443137         0.000000
# 26        0.000000         0.000000        0.447059         0.000000
# 27        0.000000         0.000000        0.447059         0.000000
# 28        0.000000         0.000000        0.447059         0.000000
# 29        0.000000         0.000000        0.443137         0.000000
#
#     Image pixel 299                                      absolute_path  \
# 0          0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 1          0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 2          0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 3          0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 4          0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 5          0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 6          0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 7          0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 8          0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 9          0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 10         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 11         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 12         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 13         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 14         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 15         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 16         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 17         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 18         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 19         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 20         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 21         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 22         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 23         0.003922  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 24         0.003922  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 25         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 26         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 27         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 28         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 29         0.000000  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#
#                                            exp_config  \
# 0   {'policy': {'_target_': 'src.policy.PendulumPo...
# 1   {'policy': {'_target_': 'src.policy.PendulumPo...
# 2   {'policy': {'_target_': 'src.policy.PendulumPo...
# 3   {'policy': {'_target_': 'src.policy.PendulumPo...
# 4   {'policy': {'_target_': 'src.policy.PendulumPo...
# 5   {'policy': {'_target_': 'src.policy.PendulumPo...
# 6   {'policy': {'_target_': 'src.policy.PendulumPo...
# 7   {'policy': {'_target_': 'src.policy.PendulumPo...
# 8   {'policy': {'_target_': 'src.policy.PendulumPo...
# 9   {'policy': {'_target_': 'src.policy.PendulumPo...
# 10  {'policy': {'_target_': 'src.policy.PendulumPo...
# 11  {'policy': {'_target_': 'src.policy.PendulumPo...
# 12  {'policy': {'_target_': 'src.policy.PendulumPo...
# 13  {'policy': {'_target_': 'src.policy.PendulumPo...
# 14  {'policy': {'_target_': 'src.policy.PendulumPo...
# 15  {'policy': {'_target_': 'src.policy.PendulumPo...
# 16  {'policy': {'_target_': 'src.policy.PendulumPo...
# 17  {'policy': {'_target_': 'src.policy.PendulumPo...
# 18  {'policy': {'_target_': 'src.policy.PendulumPo...
# 19  {'policy': {'_target_': 'src.policy.PendulumPo...
# 20  {'policy': {'_target_': 'src.policy.PendulumPo...
# 21  {'policy': {'_target_': 'src.policy.PendulumPo...
# 22  {'policy': {'_target_': 'src.policy.PendulumPo...
# 23  {'policy': {'_target_': 'src.policy.PendulumPo...
# 24  {'policy': {'_target_': 'src.policy.PendulumPo...
# 25  {'policy': {'_target_': 'src.policy.PendulumPo...
# 26  {'policy': {'_target_': 'src.policy.PendulumPo...
# 27  {'policy': {'_target_': 'src.policy.PendulumPo...
# 28  {'policy': {'_target_': 'src.policy.PendulumPo...
# 29  {'policy': {'_target_': 'src.policy.PendulumPo...
#
#                                       experiment_path  is_reset_buffer  \
# 0   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 1   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 2   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 3   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 4   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 5   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 6   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 7   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 8   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 9   /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 10  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 11  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 12  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 13  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 14  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 15  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 16  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 17  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 18  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 19  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 20  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 21  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 22  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 23  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 24  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 25  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 26  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 27  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 28  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# 29  /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#
#     learning_starts
# 0               400
# 1               400
# 2               400
# 3               400
# 4               400
# 5               400
# 6               400
# 7               400
# 8               400
# 9               400
# 10              400
# 11              400
# 12              400
# 13              400
# 14              400
# 15              400
# 16              400
# 17              400
# 18              400
# 19              400
# 20              400
# 21              400
# 22              400
# 23              400
# 24              400
# 25              400
# 26              400
# 27              400
# 28              400
# 29              400
#
# [30 rows x 321 columns]

# %%
df.running_objective.describe()
# Out:
# count    16480.000000
# mean         0.447585
# std          0.423411
# min         -1.000000
# 25%          0.000000
# 50%          0.489796
# 75%          0.816327
# max          0.979592
# Name: running_objective, dtype: float64

# %%
def postprocess_linefollowing(df):
    if not df.index.is_integer():
        df = df.reset_index()

    df["catch_the_line"] = df.running_objective.apply(lambda x: x > 0.7)
    return df

# %%
df = postprocess_linefollowing(df)

analyse_group_df = df[df.phase == "eval"].reset_index().groupby(["task_name", "iteration_id"])

if "catch_the_line" in df.columns:
    agg = dict.fromkeys(df.columns.difference(['catch_the_line', "task_name", "iteration_id"]), 'last')
    agg['catch_the_line'] = 'sum'

    analyse_group_df = analyse_group_df.agg(agg)
else:
    analyse_group_df = analyse_group_df.last()

analyse_group_df
# Out:
# /tmp/ipykernel_2879362/3626384526.py:2: FutureWarning: RangeIndex.is_integer is deprecated. Use pandas.api.types.is_integer_dtype instead.
#   if not df.index.is_integer():
#                             Angular Velocity [rad/s]  Image pixel 0  \
# task_name     iteration_id
# circle_blue   724                           0.061800       0.000000
#               725                          -1.207327       0.000000
#               726                          -0.444242       0.000000
#               727                          -0.285463       0.000000
# circle_green  720                           0.588607       0.000000
#               721                          -1.320921       0.000000
#               722                          -1.227777       0.000000
#               723                          -1.550767       0.000000
# circle_red    716                           0.503757       0.470588
#               717                           1.157124       0.474510
#               718                           0.511075       0.470588
#               719                          -1.115061       0.462745
# circle_yellow 728                          -1.334773       0.458824
#               729                          -0.118853       0.466667
#               730                          -0.194684       0.466667
#               731                           0.962884       0.466667
#
#                             Image pixel 1  Image pixel 10  Image pixel 100  \
# task_name     iteration_id
# circle_blue   724                0.000000        0.000000              0.0
#               725                0.000000        0.000000              0.0
#               726                0.000000        0.000000              0.0
#               727                0.000000        0.000000              0.0
# circle_green  720                0.372549        0.376471              0.0
#               721                0.372549        0.372549              0.0
#               722                0.380392        0.380392              0.0
#               723                0.000000        0.000000              0.0
# circle_red    716                0.000000        0.000000              0.0
#               717                0.000000        0.000000              0.0
#               718                0.000000        0.000000              0.0
#               719                0.000000        0.000000              0.0
# circle_yellow 728                0.458824        0.462745              0.0
#               729                0.466667        0.466667              0.0
#               730                0.466667        0.466667              0.0
#               731                0.466667        0.466667              0.0
#
#                             Image pixel 101  Image pixel 102  Image pixel 103  \
# task_name     iteration_id
# circle_blue   724                   0.00000              0.0              0.0
#               725                   0.00000              0.0              0.0
#               726                   0.00000              0.0              0.0
#               727                   0.47451              0.0              0.0
# circle_green  720                   0.00000              0.0              0.0
#               721                   0.00000              0.0              0.0
#               722                   0.00000              0.0              0.0
#               723                   0.00000              0.0              0.0
# circle_red    716                   0.00000              0.0              0.0
#               717                   0.00000              0.0              0.0
#               718                   0.00000              0.0              0.0
#               719                   0.00000              0.0              0.0
# circle_yellow 728                   0.00000              0.0              0.0
#               729                   0.00000              0.0              0.0
#               730                   0.00000              0.0              0.0
#               731                   0.00000              0.0              0.0
#
#                             Image pixel 104  Image pixel 105  ...  \
# task_name     iteration_id                                    ...
# circle_blue   724                  0.000000              0.0  ...
#               725                  0.000000              0.0  ...
#               726                  0.000000              0.0  ...
#               727                  0.470588              0.0  ...
# circle_green  720                  0.000000              0.0  ...
#               721                  0.000000              0.0  ...
#               722                  0.000000              0.0  ...
#               723                  0.000000              0.0  ...
# circle_red    716                  0.000000              0.0  ...
#               717                  0.000000              0.0  ...
#               718                  0.000000              0.0  ...
#               719                  0.000000              0.0  ...
# circle_yellow 728                  0.000000              0.0  ...
#               729                  0.000000              0.0  ...
#               730                  0.000000              0.0  ...
#               731                  0.000000              0.0  ...
#
#                                                               experiment_path  \
# task_name     iteration_id
# circle_blue   724           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#               725           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#               726           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#               727           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# circle_green  720           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#               721           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#               722           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#               723           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# circle_red    716           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#               717           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#               718           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#               719           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# circle_yellow 728           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#               729           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#               730           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#               731           /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#
#                             exploration  index  is_reset_buffer  \
# task_name     iteration_id
# circle_blue   724                 False     29
#               725                 False     29
#               726                 False     29
#               727                 False     29
# circle_green  720                 False     29
#               721                 False     29
#               722                 False     29
#               723                 False     29
# circle_red    716                 False     50
#               717                 False     29
#               718                 False     29
#               719                 False     29
# circle_yellow 728                 False     29
#               729                 False     29
#               730                 False     29
#               731                 False     29
#
#                             learning_starts  phase  running_objective  \
# task_name     iteration_id
# circle_blue   724                       400   eval           0.775510
#               725                       400   eval           0.000000
#               726                       400   eval           0.816327
#               727                       400   eval           0.000000
# circle_green  720                       400   eval           0.979592
#               721                       400   eval           0.857143
#               722                       400   eval           0.816327
#               723                       400   eval           0.000000
# circle_red    716                       400   eval           0.897959
#               717                       400   eval           0.979592
#               718                       400   eval           0.897959
#               719                       400   eval           0.938776
# circle_yellow 728                       400   eval           0.897959
#               729                       400   eval           0.979592
#               730                       400   eval           0.979592
#               731                       400   eval           0.979592
#
#                             step_id  time  catch_the_line
# task_name     iteration_id
# circle_blue   724                29  4.62              29
#               725                59  4.62               0
#               726                89  4.62               3
#               727               119  4.62               0
# circle_green  720                29  4.62              29
#               721                59  4.62              29
#               722                89  4.62              29
#               723               119  4.62               7
# circle_red    716                29  4.62              23
#               717                59  4.62              29
#               718                89  4.62              21
#               719               119  4.62              30
# circle_yellow 728                29  4.62              21
#               729                59  4.62              18
#               730                89  4.62              30
#               731               119  4.62              25
#
# [16 rows x 320 columns]

# %%
df = postprocess_linefollowing(df)

if "eval" in df.phase.unique():
    analyse_group_df = df[df.phase == "eval"].reset_index().groupby(["task_name", "iteration_id"])

    if "catch_the_line" in df.columns:
        agg = dict.fromkeys(df.columns.difference(['catch_the_line', "task_name", "iteration_id"]), 'last')
        agg['catch_the_line'] = 'sum'

        analyse_group_df = analyse_group_df.agg(agg)
    else:
        analyse_group_df = analyse_group_df.last()

    def is_solved_task(row):
        if row.category == "LineFollowing":
            return row.catch_the_line > 20

        if row.category == "PushingObject":
            if row.task_name in ["blue", "yellow"]:
                return row.running_objective == 10
            
            if row.task_name in ["red", "green"]:
                return row.running_objective != -10

        return False

    def aggregate_function(series):
        sucess = np.sum(series)
        total = series.count()
        return "{:02.0f} / {:02.0f} = {:03.2f}".format(sucess, total, np.round(sucess / total, 2))

    analyse_group_df = analyse_group_df.reset_index()
    analyse_group_df["completion"] = analyse_group_df.apply(is_solved_task, axis=1)
    # analyse_group_df = analyse_group_df.set_index(['controller', 'category', 'buffer_size'])

    pivot_table = pd.pivot_table(
        analyse_group_df.reset_index(), 
        columns=['controller', 'buffer_size'],
        index=["category", "task_name"], 
        values="completion", aggfunc=aggregate_function
    )
    
else:
    pivot_table = None

pivot_table
# Out:
# /tmp/ipykernel_2879362/3626384526.py:2: FutureWarning: RangeIndex.is_integer is deprecated. Use pandas.api.types.is_integer_dtype instead.
#   if not df.index.is_integer():
# controller                              SAC
# buffer_size                           16000
# category      task_name
# LineFollowing circle_blue    01 / 04 = 0.25
#               circle_green   03 / 04 = 0.75
#               circle_red     04 / 04 = 1.00
#               circle_yellow  03 / 04 = 0.75

# %%
analyse_group_df.set_index(["task_name", "iteration_id"]).loc[:, ["catch_the_line"]]
# Out:
#                             catch_the_line
# task_name     iteration_id
# circle_blue   724                       29
#               725                        0
#               726                        3
#               727                        0
# circle_green  720                       29
#               721                       29
#               722                       29
#               723                        7
# circle_red    716                       23
#               717                       29
#               718                       21
#               719                       30
# circle_yellow 728                       21
#               729                       18
#               730                       30
#               731                       25

# %%
tmp_df = df.loc[:, ["iteration_id", "step_id", "task_name", "current_undiscounted_value", "learning_starts", "phase"]]
tmp_df = tmp_df[np.invert(np.logical_and(tmp_df.phase == "train", tmp_df.step_id <= tmp_df.learning_starts))]
g = tmp_df.groupby("iteration_id").last()
g = g.reset_index()
g.iteration_id = g.reset_index().index
g.plot(y="current_undiscounted_value")
g.set_index("iteration_id")
# Out:
#               step_id      task_name  current_undiscounted_value  \
# iteration_id
# 0                 428     circle_red                   16.408163
# 1                 434     circle_red                   -0.469388
# 2                 449     circle_red                    5.448980
# 3                 462     circle_red                    3.653061
# 4                 473     circle_red                   -0.183673
# ...               ...            ...                         ...
# 640               119    circle_blue                    1.714286
# 641                29  circle_yellow                   24.000000
# 642                59  circle_yellow                   23.102041
# 643                89  circle_yellow                   28.489796
# 644               119  circle_yellow                   25.632653
#
#               learning_starts  phase
# iteration_id
# 0                         400  train
# 1                         400  train
# 2                         400  train
# 3                         400  train
# 4                         400  train
# ...                       ...    ...
# 640                       400   eval
# 641                       400   eval
# 642                       400   eval
# 643                       400   eval
# 644                       400   eval
#
# [645 rows x 5 columns]

# %%
# df = df.reset_index().set_index(["controller", "category", "buffer_size", "task_name"])
# df[df.running_objective == 10].loc[['SAC']]

# %%
df = df.reset_index().set_index(["controller", "category", "buffer_size", "task_name"])
df = df.reset_index().set_index(group_df.index.names)
tmp_df = df.loc[group_df.index]

tmp_group_df = tmp_df.loc[:, ["iteration_id", "step_id", "task_name", "current_undiscounted_value", "phase"]].groupby("iteration_id")
tmp_group_df = tmp_group_df.aggregate({
    "current_undiscounted_value": "mean", 
    "task_name": "last",
    "step_id": "last",
    "phase": "last"
    })
tmp_group_df[tmp_group_df.phase=="eval"].plot(y="current_undiscounted_value")
# Out:
# <Axes: xlabel='iteration_id'>

# %%
check_df = tmp_df[tmp_df.phase == "eval"]

for iter in check_df.iteration_id.unique():
    t_df = check_df[check_df.iteration_id == iter]
    t_df.plot(x="step_id", y="current_undiscounted_value", title=f"{t_df.task_name.values[0]} - {t_df.iteration_id.values[0]}")

# %%
[c for c in check_df.columns]
# Out:
# ['task_name',
#  'level_0',
#  'index',
#  'time',
#  'running_objective',
#  'current_value',
#  'current_undiscounted_value',
#  'episode_id',
#  'iteration_id',
#  'step_id',
#  'phase',
#  'exploration',
#  'Linear Velocity [m/s]',
#  'Angular Velocity [rad/s]',
#  'Image pixel 0',
#  'Image pixel 1',
#  'Image pixel 2',
#  'Image pixel 3',
#  'Image pixel 4',
#  'Image pixel 5',
#  'Image pixel 6',
#  'Image pixel 7',
#  'Image pixel 8',
#  'Image pixel 9',
#  'Image pixel 10',
#  'Image pixel 11',
#  'Image pixel 12',
#  'Image pixel 13',
#  'Image pixel 14',
#  'Image pixel 15',
#  'Image pixel 16',
#  'Image pixel 17',
#  'Image pixel 18',
#  'Image pixel 19',
#  'Image pixel 20',
#  'Image pixel 21',
#  'Image pixel 22',
#  'Image pixel 23',
#  'Image pixel 24',
#  'Image pixel 25',
#  'Image pixel 26',
#  'Image pixel 27',
#  'Image pixel 28',
#  'Image pixel 29',
#  'Image pixel 30',
#  'Image pixel 31',
#  'Image pixel 32',
#  'Image pixel 33',
#  'Image pixel 34',
#  'Image pixel 35',
#  'Image pixel 36',
#  'Image pixel 37',
#  'Image pixel 38',
#  'Image pixel 39',
#  'Image pixel 40',
#  'Image pixel 41',
#  'Image pixel 42',
#  'Image pixel 43',
#  'Image pixel 44',
#  'Image pixel 45',
#  'Image pixel 46',
#  'Image pixel 47',
#  'Image pixel 48',
#  'Image pixel 49',
#  'Image pixel 50',
#  'Image pixel 51',
#  'Image pixel 52',
#  'Image pixel 53',
#  'Image pixel 54',
#  'Image pixel 55',
#  'Image pixel 56',
#  'Image pixel 57',
#  'Image pixel 58',
#  'Image pixel 59',
#  'Image pixel 60',
#  'Image pixel 61',
#  'Image pixel 62',
#  'Image pixel 63',
#  'Image pixel 64',
#  'Image pixel 65',
#  'Image pixel 66',
#  'Image pixel 67',
#  'Image pixel 68',
#  'Image pixel 69',
#  'Image pixel 70',
#  'Image pixel 71',
#  'Image pixel 72',
#  'Image pixel 73',
#  'Image pixel 74',
#  'Image pixel 75',
#  'Image pixel 76',
#  'Image pixel 77',
#  'Image pixel 78',
#  'Image pixel 79',
#  'Image pixel 80',
#  'Image pixel 81',
#  'Image pixel 82',
#  'Image pixel 83',
#  'Image pixel 84',
#  'Image pixel 85',
#  'Image pixel 86',
#  'Image pixel 87',
#  'Image pixel 88',
#  'Image pixel 89',
#  'Image pixel 90',
#  'Image pixel 91',
#  'Image pixel 92',
#  'Image pixel 93',
#  'Image pixel 94',
#  'Image pixel 95',
#  'Image pixel 96',
#  'Image pixel 97',
#  'Image pixel 98',
#  'Image pixel 99',
#  'Image pixel 100',
#  'Image pixel 101',
#  'Image pixel 102',
#  'Image pixel 103',
#  'Image pixel 104',
#  'Image pixel 105',
#  'Image pixel 106',
#  'Image pixel 107',
#  'Image pixel 108',
#  'Image pixel 109',
#  'Image pixel 110',
#  'Image pixel 111',
#  'Image pixel 112',
#  'Image pixel 113',
#  'Image pixel 114',
#  'Image pixel 115',
#  'Image pixel 116',
#  'Image pixel 117',
#  'Image pixel 118',
#  'Image pixel 119',
#  'Image pixel 120',
#  'Image pixel 121',
#  'Image pixel 122',
#  'Image pixel 123',
#  'Image pixel 124',
#  'Image pixel 125',
#  'Image pixel 126',
#  'Image pixel 127',
#  'Image pixel 128',
#  'Image pixel 129',
#  'Image pixel 130',
#  'Image pixel 131',
#  'Image pixel 132',
#  'Image pixel 133',
#  'Image pixel 134',
#  'Image pixel 135',
#  'Image pixel 136',
#  'Image pixel 137',
#  'Image pixel 138',
#  'Image pixel 139',
#  'Image pixel 140',
#  'Image pixel 141',
#  'Image pixel 142',
#  'Image pixel 143',
#  'Image pixel 144',
#  'Image pixel 145',
#  'Image pixel 146',
#  'Image pixel 147',
#  'Image pixel 148',
#  'Image pixel 149',
#  'Image pixel 150',
#  'Image pixel 151',
#  'Image pixel 152',
#  'Image pixel 153',
#  'Image pixel 154',
#  'Image pixel 155',
#  'Image pixel 156',
#  'Image pixel 157',
#  'Image pixel 158',
#  'Image pixel 159',
#  'Image pixel 160',
#  'Image pixel 161',
#  'Image pixel 162',
#  'Image pixel 163',
#  'Image pixel 164',
#  'Image pixel 165',
#  'Image pixel 166',
#  'Image pixel 167',
#  'Image pixel 168',
#  'Image pixel 169',
#  'Image pixel 170',
#  'Image pixel 171',
#  'Image pixel 172',
#  'Image pixel 173',
#  'Image pixel 174',
#  'Image pixel 175',
#  'Image pixel 176',
#  'Image pixel 177',
#  'Image pixel 178',
#  'Image pixel 179',
#  'Image pixel 180',
#  'Image pixel 181',
#  'Image pixel 182',
#  'Image pixel 183',
#  'Image pixel 184',
#  'Image pixel 185',
#  'Image pixel 186',
#  'Image pixel 187',
#  'Image pixel 188',
#  'Image pixel 189',
#  'Image pixel 190',
#  'Image pixel 191',
#  'Image pixel 192',
#  'Image pixel 193',
#  'Image pixel 194',
#  'Image pixel 195',
#  'Image pixel 196',
#  'Image pixel 197',
#  'Image pixel 198',
#  'Image pixel 199',
#  'Image pixel 200',
#  'Image pixel 201',
#  'Image pixel 202',
#  'Image pixel 203',
#  'Image pixel 204',
#  'Image pixel 205',
#  'Image pixel 206',
#  'Image pixel 207',
#  'Image pixel 208',
#  'Image pixel 209',
#  'Image pixel 210',
#  'Image pixel 211',
#  'Image pixel 212',
#  'Image pixel 213',
#  'Image pixel 214',
#  'Image pixel 215',
#  'Image pixel 216',
#  'Image pixel 217',
#  'Image pixel 218',
#  'Image pixel 219',
#  'Image pixel 220',
#  'Image pixel 221',
#  'Image pixel 222',
#  'Image pixel 223',
#  'Image pixel 224',
#  'Image pixel 225',
#  'Image pixel 226',
#  'Image pixel 227',
#  'Image pixel 228',
#  'Image pixel 229',
#  'Image pixel 230',
#  'Image pixel 231',
#  'Image pixel 232',
#  'Image pixel 233',
#  'Image pixel 234',
#  'Image pixel 235',
#  'Image pixel 236',
#  'Image pixel 237',
#  'Image pixel 238',
#  'Image pixel 239',
#  'Image pixel 240',
#  'Image pixel 241',
#  'Image pixel 242',
#  'Image pixel 243',
#  'Image pixel 244',
#  'Image pixel 245',
#  'Image pixel 246',
#  'Image pixel 247',
#  'Image pixel 248',
#  'Image pixel 249',
#  'Image pixel 250',
#  'Image pixel 251',
#  'Image pixel 252',
#  'Image pixel 253',
#  'Image pixel 254',
#  'Image pixel 255',
#  'Image pixel 256',
#  'Image pixel 257',
#  'Image pixel 258',
#  'Image pixel 259',
#  'Image pixel 260',
#  'Image pixel 261',
#  'Image pixel 262',
#  'Image pixel 263',
#  'Image pixel 264',
#  'Image pixel 265',
#  'Image pixel 266',
#  'Image pixel 267',
#  'Image pixel 268',
#  'Image pixel 269',
#  'Image pixel 270',
#  'Image pixel 271',
#  'Image pixel 272',
#  'Image pixel 273',
#  'Image pixel 274',
#  'Image pixel 275',
#  'Image pixel 276',
#  'Image pixel 277',
#  'Image pixel 278',
#  'Image pixel 279',
#  'Image pixel 280',
#  'Image pixel 281',
#  'Image pixel 282',
#  'Image pixel 283',
#  'Image pixel 284',
#  'Image pixel 285',
#  'Image pixel 286',
#  'Image pixel 287',
#  'Image pixel 288',
#  'Image pixel 289',
#  'Image pixel 290',
#  'Image pixel 291',
#  'Image pixel 292',
#  'Image pixel 293',
#  'Image pixel 294',
#  'Image pixel 295',
#  'Image pixel 296',
#  'Image pixel 297',
#  'Image pixel 298',
#  'Image pixel 299',
#  'absolute_path',
#  'exp_config',
#  'experiment_path',
#  'is_reset_buffer',
#  'learning_starts',
#  'catch_the_line']

# %%
check_df = tmp_df[tmp_df.phase == "eval"]

t_df = check_df[check_df.iteration_id == 900]

def plot_eval(df, title):
    plt.figure(figsize=(12, 6))
    ax1 = plt.subplot(1, 2, 1)
    ax1.set_ylabel("Accumulated reward")
    df.plot(x="step_id", y="current_undiscounted_value", title=title, ax=ax1)

    ax2 = plt.subplot(2, 2, 2)
    df.plot(x="time", 
            y="Linear Velocity [m/s]", ax=ax2, color="tab:orange", title="Linear velocity")

    ax3 = plt.subplot(2, 2, 4)
    df.plot(x="time", 
            y="Angular Velocity [rad/s]", ax=ax3, color="tab:blue", title="Angular velocity")

    plt.tight_layout()

# %%
plot_eval(check_df[check_df.iteration_id == 1], title="Pushing Object Red Object")
plot_eval(check_df[check_df.iteration_id == 903], title="Pushing Object Blue Object")
plot_eval(check_df[check_df.iteration_id == 907], title="Pushing Object Green Object")
plot_eval(check_df[check_df.iteration_id == 913], title="Pushing Object Yellow Object")

# %%
t_df
# Out:
# Empty DataFrame
# Columns: [task_name, level_0, index, time, running_objective, current_value, current_undiscounted_value, episode_id, iteration_id, step_id, phase, exploration, Linear Velocity [m/s], Angular Velocity [rad/s], Image pixel 0, Image pixel 1, Image pixel 2, Image pixel 3, Image pixel 4, Image pixel 5, Image pixel 6, Image pixel 7, Image pixel 8, Image pixel 9, Image pixel 10, Image pixel 11, Image pixel 12, Image pixel 13, Image pixel 14, Image pixel 15, Image pixel 16, Image pixel 17, Image pixel 18, Image pixel 19, Image pixel 20, Image pixel 21, Image pixel 22, Image pixel 23, Image pixel 24, Image pixel 25, Image pixel 26, Image pixel 27, Image pixel 28, Image pixel 29, Image pixel 30, Image pixel 31, Image pixel 32, Image pixel 33, Image pixel 34, Image pixel 35, Image pixel 36, Image pixel 37, Image pixel 38, Image pixel 39, Image pixel 40, Image pixel 41, Image pixel 42, Image pixel 43, Image pixel 44, Image pixel 45, Image pixel 46, Image pixel 47, Image pixel 48, Image pixel 49, Image pixel 50, Image pixel 51, Image pixel 52, Image pixel 53, Image pixel 54, Image pixel 55, Image pixel 56, Image pixel 57, Image pixel 58, Image pixel 59, Image pixel 60, Image pixel 61, Image pixel 62, Image pixel 63, Image pixel 64, Image pixel 65, Image pixel 66, Image pixel 67, Image pixel 68, Image pixel 69, Image pixel 70, Image pixel 71, Image pixel 72, Image pixel 73, Image pixel 74, Image pixel 75, Image pixel 76, Image pixel 77, Image pixel 78, Image pixel 79, Image pixel 80, Image pixel 81, Image pixel 82, Image pixel 83, Image pixel 84, Image pixel 85, ...]
# Index: []
#
# [0 rows x 320 columns]

# %%
check_df
# Out:
#                                           task_name  level_0  index   time  \
# controller category      buffer_size
# SAC        LineFollowing 16000           circle_red    15981     21  0.000
#                          16000           circle_red    15982     22  0.000
#                          16000           circle_red    15984     23  0.165
#                          16000           circle_red    15985     24  0.330
#                          16000           circle_red    15987     25  0.495
# ...                                             ...      ...    ...    ...
#                          16000        circle_yellow    16475     25  3.960
#                          16000        circle_yellow    16476     26  4.125
#                          16000        circle_yellow    16477     27  4.290
#                          16000        circle_yellow    16478     28  4.455
#                          16000        circle_yellow    16479     29  4.620
#
#                                       running_objective current_value  \
# controller category      buffer_size
# SAC        LineFollowing 16000                 0.489796          None
#                          16000                 0.489796          None
#                          16000                 0.530612          None
#                          16000                 0.571429          None
#                          16000                 0.612245          None
# ...                                                 ...           ...
#                          16000                 0.979592          None
#                          16000                 0.979592          None
#                          16000                 0.979592          None
#                          16000                 0.979592          None
#                          16000                 0.979592          None
#
#                                       current_undiscounted_value  episode_id  \
# controller category      buffer_size
# SAC        LineFollowing 16000                         20.530612           1
#                          16000                         21.020408           1
#                          16000                         21.551020           1
#                          16000                         22.122449           1
#                          16000                         22.734694           1
# ...                                                          ...         ...
#                          16000                         21.714286           1
#                          16000                         22.693878           1
#                          16000                         23.673469           1
#                          16000                         24.653061           1
#                          16000                         25.632653           1
#
#                                       iteration_id  step_id  ...  \
# controller category      buffer_size                         ...
# SAC        LineFollowing 16000                 716        0  ...
#                          16000                 716        1  ...
#                          16000                 716        2  ...
#                          16000                 716        3  ...
#                          16000                 716        4  ...
# ...                                            ...      ...  ...
#                          16000                 731      115  ...
#                          16000                 731      116  ...
#                          16000                 731      117  ...
#                          16000                 731      118  ...
#                          16000                 731      119  ...
#
#                                      Image pixel 296  Image pixel 297  \
# controller category      buffer_size
# SAC        LineFollowing 16000                   0.0         0.466667
#                          16000                   0.0         0.462745
#                          16000                   0.0         0.458824
#                          16000                   0.0         0.458824
#                          16000                   0.0         0.454902
# ...                                              ...              ...
#                          16000                   0.0         0.000000
#                          16000                   0.0         0.000000
#                          16000                   0.0         0.000000
#                          16000                   0.0         0.000000
#                          16000                   0.0         0.000000
#
#                                       Image pixel 298  Image pixel 299  \
# controller category      buffer_size
# SAC        LineFollowing 16000                    0.0              0.0
#                          16000                    0.0              0.0
#                          16000                    0.0              0.0
#                          16000                    0.0              0.0
#                          16000                    0.0              0.0
# ...                                               ...              ...
#                          16000                    0.0              0.0
#                          16000                    0.0              0.0
#                          16000                    0.0              0.0
#                          16000                    0.0              0.0
#                          16000                    0.0              0.0
#
#                                                                           absolute_path  \
# controller category      buffer_size
# SAC        LineFollowing 16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# ...                                                                                 ...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#
#                                                                              exp_config  \
# controller category      buffer_size
# SAC        LineFollowing 16000        {'policy': {'_target_': 'src.policy.PendulumPo...
#                          16000        {'policy': {'_target_': 'src.policy.PendulumPo...
#                          16000        {'policy': {'_target_': 'src.policy.PendulumPo...
#                          16000        {'policy': {'_target_': 'src.policy.PendulumPo...
#                          16000        {'policy': {'_target_': 'src.policy.PendulumPo...
# ...                                                                                 ...
#                          16000        {'policy': {'_target_': 'src.policy.PendulumPo...
#                          16000        {'policy': {'_target_': 'src.policy.PendulumPo...
#                          16000        {'policy': {'_target_': 'src.policy.PendulumPo...
#                          16000        {'policy': {'_target_': 'src.policy.PendulumPo...
#                          16000        {'policy': {'_target_': 'src.policy.PendulumPo...
#
#                                                                         experiment_path  \
# controller category      buffer_size
# SAC        LineFollowing 16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
# ...                                                                                 ...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#                          16000        /home/tcc/huyhoang/irlc_2025/regelum-playgroun...
#
#                                       is_reset_buffer  learning_starts  \
# controller category      buffer_size
# SAC        LineFollowing 16000                                     400
#                          16000                                     400
#                          16000                                     400
#                          16000                                     400
#                          16000                                     400
# ...                                               ...              ...
#                          16000                                     400
#                          16000                                     400
#                          16000                                     400
#                          16000                                     400
#                          16000                                     400
#
#                                       catch_the_line
# controller category      buffer_size
# SAC        LineFollowing 16000                 False
#                          16000                 False
#                          16000                 False
#                          16000                 False
#                          16000                 False
# ...                                              ...
#                          16000                  True
#                          16000                  True
#                          16000                  True
#                          16000                  True
#                          16000                  True
#
# [480 rows x 320 columns]

# %%
for id in group_df.index:
    plot_learning_curve(id, group_df.index.names, df[df.phase=="eval"], title="Evaluation")

# %%
# # df = df.reset_index()
# pixel_columns = [c for c in df.columns if "pixel" in c.lower()]
# chosen_state = np.array(df.loc[:, pixel_columns].iloc[-1])
# im = chosen_state.reshape((20, 20, 3))
# # im = chosen_state.reshape((20, 20, 3))

# plt.imshow(im)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 4
#       2 pixel_columns = [c for c in df.columns if "pixel" in c.lower()]
#       3 chosen_state = np.array(df.loc[:, pixel_columns].iloc[-1])
# ----> 4 im = chosen_state.reshape((20, 20, 3))
#       5 # im = chosen_state.reshape((20, 20, 3))
#       7 plt.imshow(im)
#
# ValueError: cannot reshape array of size 300 into shape (20,20,3)

# %%
import math

def linefollowing_obj(observation):
    truncated = False

    gray_img = observation.mean(axis=2) ;
    c = observation.shape[1] ;
    black_mask = (gray_img[0,:] < 0.1) ;

    if black_mask.astype(np.int32).sum() < 1: # no black pixels visible
        terminated = True
        return -1.

    x_indices = np.linspace(0.,c,c) ;
    black_indices = x_indices[black_mask] ;
    left_line_index = np.min(black_indices) ;
    
    ret = 1.- math.fabs(left_line_index-c//2) / (c//2) ;

    terminated = ret < 0.
    return ret

# %%
from notebooks.check_model import Actor
import torch

checkpoint_path = "notebooks/actor"
actor = Actor(dim_observation=2*50*3*3, dim_action=2, action_bounds=np.array([[0.2, 0.2],[-1.57, 1.57]]))
actor.load_state_dict(torch.load(checkpoint_path))
# actions, _, _ = actor.get_action(torch.Tensor(obs))

class Robot3PiLineFollowing(object):
    def glue_images(self, img):
        if self.step_count == 0:
          self.img0 = self.img1 = img ;
        elif self.step_count == 1:
          self.img0 = self.img1 ;
          self.img1 = img ;
        ret = np.concatenate([self.img0,self.img1,img]) ;
        self.img0 = self.img1 ; self.img1 = img ;
        return ret ;
    
    def get_observation(self, **kwargs):
        return self.glue_images(self.state)
# Out:
# /tmp/ipykernel_2879362/338714258.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   actor.load_state_dict(torch.load(checkpoint_path))

# %%
df = df.reset_index().set_index(group_df.index.names)
tmp_df = df.loc[('SAC', 'LineFollowing', 16000)]
tmp_df = tmp_df[tmp_df.iteration_id == 500]
# tmp_df = tmp_df[tmp_df.iteration_id == 700]
# tmp_df = tmp_df[tmp_df.iteration_id == 300]
# tmp_df = tmp_df[tmp_df.iteration_id == 200]
# fig, ax = plt.subplots(len(tmp_df), figsize=(8, 10))
fig, ax = plt.subplots(len(tmp_df), figsize=(15, 15))

brightness_cal = lambda image: np.mean(0.299 * image[:, :, 2] + 0.587 * image[:, :, 1] + 0.114 * image[:, :, 0])

lf_object = Robot3PiLineFollowing()
for i, (_, s) in enumerate(tmp_df.iterrows()):
    pixel_columns = [c for c in s.index if "pixel" in c.lower()]
    im = np.array(s.loc[pixel_columns].dropna()).reshape((2, 50, 3)).astype(float)

    reward = np.round(linefollowing_obj(im), 2)
    
    # Only apply for Blue image: inscrease brightness
    if im.mean(axis=1).sum(axis=0).argmax() == 2:
        alpha = 1.0
        beta = 32 / 255
        im = im * alpha + beta

    lf_object.state = im
    lf_object.step_count = i
    observation = torch.Tensor(lf_object.get_observation().flatten().reshape((1, -1)))

    action = actor.get_action(observation)[0].detach().numpy()
    angular = np.round(action[0, 1], 2)
    # print()
    ax[i].imshow(im)
    ax[i].set_title("{}: {} : {} : {}".format(i, reward, "left" if angular > 0 else "right", angular))
    ax[i].axis("off")

plt.tight_layout()

# %%
im.mean(axis=1).sum(axis=0).argmax()
# Out:
# 0

# %%
np.histogram(observation[0])
# Out:
# (array([768,   3,   0,   2,   2,   3,   5,   3,   9, 105]),
#  array([0.1254902 , 0.17333335, 0.22117648, 0.26901963, 0.31686276,
#         0.3647059 , 0.41254905, 0.46039218, 0.50823534, 0.55607843,
#         0.6039216 ], dtype=float32))

# %% [markdown]
# Red: (array([756,   2,   3,   3,   6,   5,   4,   9,   7, 105]),
#  array([0.1254902 , 0.17215687, 0.21882354, 0.2654902 , 0.3121569 ,
#         0.35882354, 0.40549022, 0.45215687, 0.49882355, 0.5454902 ,
#         0.5921569 ], dtype=float32))

# %%
# from src.objective import RobotPursuitRunningObjective

# objective_func = RobotPursuitRunningObjective()

# objective_func(state=im, 
#                catcher_pos=[1, 1], 
#                runner_pos=[0, 0], 
#                action=[1, 0], 
#                step_count=0, 
#                max_steps_per_episode=100,
#                runner_collision_thickness=0.49,
#                arena_bounds=[-2.5,2.5,-2.5,2.5],
#                info={})

# %%
import numpy as np
np.sum(im)
# Out:
# 695.2667

# %%
plot_learning_curve(('SAC', 'LineFollowing', False), group_df.index.names, df)
plot_learning_curve(('SAC', 'LineFollowing', True), group_df.index.names, df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1014], line 1
# ----> 1 plot_learning_curve(('SAC', 'LineFollowing', False), group_df.index.names, df)
#       2 plot_learning_curve(('SAC', 'LineFollowing', True), group_df.index.names, df)
#
# Cell In[994], line 9, in plot_learning_curve(index, index_names, df, title)
#       6 fig, ax = plt.subplots(figsize=(10,3))
#       8 df = df.reset_index().set_index(index_names)
# ----> 9 tmp_df = df.loc[index]
#      11 # Filter exploration actions
#      12 tmp_df = tmp_df.loc[:, ["iteration_id", "step_id", "task_name", "current_undiscounted_value", "learning_starts", "phase"]]
#
# File ~/huyhoang/irlc_2025/regelum-playground-iclr/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~/huyhoang/irlc_2025/regelum-playground-iclr/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1368, in _LocIndexer._getitem_tuple(self, tup)
#    1366 with suppress(IndexingError):
#    1367     tup = self._expand_ellipsis(tup)
# -> 1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
#    1371 tup = self._validate_tuple_indexer(tup)
#
# File ~/huyhoang/irlc_2025/regelum-playground-iclr/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1057, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1047 if (
#    1048     isinstance(ax0, MultiIndex)
#    1049     and self.name != "iloc"
#    (...)
#    1054     #  is equivalent.
#    1055     #  (see the other place where we call _handle_lowerdim_multi_index_axis0)
#    1056     with suppress(IndexingError):
# -> 1057         return cast(_LocIndexer, self)._handle_lowerdim_multi_index_axis0(tup)
#    1059 tup = self._validate_key_length(tup)
#    1061 for i, key in enumerate(tup):
#
# File ~/huyhoang/irlc_2025/regelum-playground-iclr/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1394, in _LocIndexer._handle_lowerdim_multi_index_axis0(self, tup)
#    1390 except KeyError as ek:
#    1391     # raise KeyError if number of indexers match
#    1392     # else IndexingError will be raised
#    1393     if self.ndim < len(tup) <= self.obj.index.nlevels:
# -> 1394         raise ek
#    1395     raise IndexingError("No label returned") from ek
#
# File ~/huyhoang/irlc_2025/regelum-playground-iclr/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1388, in _LocIndexer._handle_lowerdim_multi_index_axis0(self, tup)
#    1385 axis = self.axis or 0
#    1386 try:
#    1387     # fast path for series or for tup devoid of slices
# -> 1388     return self._get_label(tup, axis=axis)
#    1390 except KeyError as ek:
#    1391     # raise KeyError if number of indexers match
#    1392     # else IndexingError will be raised
#    1393     if self.ndim < len(tup) <= self.obj.index.nlevels:
#
# File ~/huyhoang/irlc_2025/regelum-playground-iclr/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
#    1380     # GH#5567 this will fail if the label is not present in the axis.
# -> 1381     return self.obj.xs(label, axis=axis)
#
# File ~/huyhoang/irlc_2025/regelum-playground-iclr/venv/lib/python3.10/site-packages/pandas/core/generic.py:4293, in NDFrame.xs(self, key, axis, level, drop_level)
#    4290     index = self.index
#    4292 if isinstance(index, MultiIndex):
# -> 4293     loc, new_index = index._get_loc_level(key, level=0)
#    4294     if not drop_level:
#    4295         if lib.is_integer(loc):
#    4296             # Slice index must be an integer or None
#
# File ~/huyhoang/irlc_2025/regelum-playground-iclr/venv/lib/python3.10/site-packages/pandas/core/indexes/multi.py:3229, in MultiIndex._get_loc_level(self, key, level)
#    3226         pass
#    3228 # partial selection
# -> 3229 indexer = self.get_loc(key)
#    3230 ilevels = [i for i in range(len(key)) if key[i] != slice(None, None)]
#    3231 if len(ilevels) == self.nlevels:
#
# File ~/huyhoang/irlc_2025/regelum-playground-iclr/venv/lib/python3.10/site-packages/pandas/core/indexes/multi.py:3080, in MultiIndex.get_loc(self, key)
#    3077         raise KeyError(key) from err
#    3079 if start == stop:
# -> 3080     raise KeyError(key)
#    3082 if not follow_key:
#    3083     return slice(start, stop)
#
# KeyError: ('SAC', 'LineFollowing', False)

# %%
tmp_df["previous_step"] = [tmp_df.step_id.values.tolist()[0]] + tmp_df.step_id.values.tolist()[:-1]
tmp_df[(tmp_df.step_id.diff() < 0)]
# tmp_df.step_id.values.tolist()[1:]+ [tmp_df.step_id.values.tolist()[-1]]
# Out:
# /tmp/ipykernel_127043/3476527340.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp_df["previous_step"] = [tmp_df.step_id.values.tolist()[0]] + tmp_df.step_id.values.tolist()[:-1]
#                                           index   time  running_objective  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                6  0.000           0.408163
#                          False                8  0.198           0.000000
#                          False                9  0.363           0.000000
#                          False               10  0.528           0.000000
#                          False               11  0.693           0.000000
#                          False                2  0.000           0.693878
#                          False               15  0.000           0.734694
#                          False               18  0.363           0.979592
#                          False               19  0.528           0.979592
#                          False               20  0.693           0.897959
#                          False               21  0.858           0.775510
#                          False               22  1.023           0.530612
#                          False               23  1.188           0.285714
#                          False               24  1.353           0.081633
#                          False               25  1.518           0.040816
#                          False               26  1.683          -1.000000
#                          False                0  0.000           0.530612
#
#                                          current_value  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#
#                                           current_undiscounted_value  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                              2.693878
#                          False                              2.857143
#                          False                              2.857143
#                          False                              2.857143
#                          False                              2.857143
#                          False                              2.122449
#                          False                              5.755102
#                          False                              8.448980
#                          False                              9.428571
#                          False                             10.326531
#                          False                             11.102041
#                          False                             11.632653
#                          False                             11.918367
#                          False                             12.000000
#                          False                             12.040816
#                          False                             11.040816
#                          False                              0.530612
#
#                                           episode_id  iteration_id  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                     1           440
#                          False                     1           440
#                          False                     1           440
#                          False                     1           440
#                          False                     1           440
#                          False                     1           856
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1197
#
#                                               task_name  step_id  \
# controller category      is_reset_buffer
# SAC        LineFollowing False             circle_green        0
#                          False             circle_green        2
#                          False             circle_green        3
#                          False             circle_green        4
#                          False             circle_green        5
#                          False              circle_blue        0
#                          False            circle_yellow        0
#                          False            circle_yellow        3
#                          False            circle_yellow        4
#                          False            circle_yellow        5
#                          False            circle_yellow        6
#                          False            circle_yellow        7
#                          False            circle_yellow        8
#                          False            circle_yellow        9
#                          False            circle_yellow       10
#                          False            circle_yellow       11
#                          False            circle_yellow       12
#
#                                           Linear Velocity [m/s]  ...  \
# controller category      is_reset_buffer                         ...
# SAC        LineFollowing False                         0.447843  ...
#                          False                         0.083950  ...
#                          False                         0.261346  ...
#                          False                         0.390418  ...
#                          False                         0.085747  ...
#                          False                         0.341374  ...
#                          False                         0.095032  ...
#                          False                         0.275422  ...
#                          False                         0.104859  ...
#                          False                         0.368884  ...
#                          False                         0.407510  ...
#                          False                         0.331603  ...
#                          False                         0.192844  ...
#                          False                         0.243309  ...
#                          False                         0.156847  ...
#                          False                         0.413831  ...
#                          False                         0.148109  ...
#
#                                           Image pixel 1191  Image pixel 1192  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#
#                                           Image pixel 1193  Image pixel 1194  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#
#                                           Image pixel 1195  Image pixel 1196  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#
#                                           Image pixel 1197  Image pixel 1198  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#
#                                           Image pixel 1199  previous_step
# controller category      is_reset_buffer
# SAC        LineFollowing False                         NaN           5995
#                          False                         NaN           5996
#                          False                         NaN           5997
#                          False                         NaN           5998
#                          False                         NaN           5999
#                          False                         NaN           5999
#                          False                         NaN           5986
#                          False                         NaN           5988
#                          False                         NaN           5989
#                          False                         NaN           5990
#                          False                         NaN           5991
#                          False                         NaN           5992
#                          False                         NaN           5993
#                          False                         NaN           5994
#                          False                         NaN           5995
#                          False                         NaN           5996
#                          False                         NaN           5999
#
# [17 rows x 1215 columns]

# %%
tmp_df[tmp_df.iteration_id == 1196]
# Out:
#                                           index   time  running_objective  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                0  0.000           0.693878
#                          False                1  0.000           0.857143
#                          False               15  0.000           0.734694
#                          False               16  0.000           0.775510
#                          False               17  0.165           0.938776
#                          False                2  0.198           0.979592
#                          False                3  0.363           0.775510
#                          False               18  0.363           0.979592
#                          False                4  0.528           0.408163
#                          False               19  0.528           0.979592
#                          False                5  0.693           0.448980
#                          False               20  0.693           0.897959
#                          False                6  0.858           0.326531
#                          False               21  0.858           0.775510
#                          False                7  1.023           0.122449
#                          False               22  1.023           0.530612
#                          False                8  1.188           0.040816
#                          False               23  1.188           0.285714
#                          False                9  1.353           0.040816
#                          False               24  1.353           0.081633
#                          False               10  1.518           0.040816
#                          False               25  1.518           0.040816
#                          False               11  1.683           0.000000
#                          False               26  1.683          -1.000000
#                          False               12  1.848           0.081633
#                          False               13  2.013           0.081633
#                          False               14  2.178           0.122449
#
#                                          current_value  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#                          False                    None
#
#                                           current_undiscounted_value  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                              0.693878
#                          False                              1.551020
#                          False                              5.755102
#                          False                              6.530612
#                          False                              7.469388
#                          False                              2.530612
#                          False                              3.306122
#                          False                              8.448980
#                          False                              3.714286
#                          False                              9.428571
#                          False                              4.163265
#                          False                             10.326531
#                          False                              4.489796
#                          False                             11.102041
#                          False                              4.612245
#                          False                             11.632653
#                          False                              4.653061
#                          False                             11.918367
#                          False                              4.693878
#                          False                             12.000000
#                          False                              4.734694
#                          False                             12.040816
#                          False                              4.734694
#                          False                             11.040816
#                          False                              4.816327
#                          False                              4.897959
#                          False                              5.020408
#
#                                           episode_id  iteration_id  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#                          False                     1          1196
#
#                                               task_name  step_id  \
# controller category      is_reset_buffer
# SAC        LineFollowing False              circle_blue     5985
#                          False              circle_blue     5986
#                          False            circle_yellow        0
#                          False            circle_yellow        1
#                          False            circle_yellow        2
#                          False              circle_blue     5987
#                          False              circle_blue     5988
#                          False            circle_yellow        3
#                          False              circle_blue     5989
#                          False            circle_yellow        4
#                          False              circle_blue     5990
#                          False            circle_yellow        5
#                          False              circle_blue     5991
#                          False            circle_yellow        6
#                          False              circle_blue     5992
#                          False            circle_yellow        7
#                          False              circle_blue     5993
#                          False            circle_yellow        8
#                          False              circle_blue     5994
#                          False            circle_yellow        9
#                          False              circle_blue     5995
#                          False            circle_yellow       10
#                          False              circle_blue     5996
#                          False            circle_yellow       11
#                          False              circle_blue     5997
#                          False              circle_blue     5998
#                          False              circle_blue     5999
#
#                                           Linear Velocity [m/s]  ...  \
# controller category      is_reset_buffer                         ...
# SAC        LineFollowing False                         0.348570  ...
#                          False                         0.309426  ...
#                          False                         0.095032  ...
#                          False                         0.417678  ...
#                          False                         0.193976  ...
#                          False                         0.474732  ...
#                          False                         0.373912  ...
#                          False                         0.275422  ...
#                          False                         0.066363  ...
#                          False                         0.104859  ...
#                          False                         0.451064  ...
#                          False                         0.368884  ...
#                          False                         0.454819  ...
#                          False                         0.407510  ...
#                          False                         0.233611  ...
#                          False                         0.331603  ...
#                          False                         0.260371  ...
#                          False                         0.192844  ...
#                          False                         0.309722  ...
#                          False                         0.243309  ...
#                          False                         0.220111  ...
#                          False                         0.156847  ...
#                          False                         0.456930  ...
#                          False                         0.413831  ...
#                          False                         0.376724  ...
#                          False                         0.158667  ...
#                          False                         0.487163  ...
#
#                                           Image pixel 1191  Image pixel 1192  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#
#                                           Image pixel 1193  Image pixel 1194  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#
#                                           Image pixel 1195  Image pixel 1196  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#
#                                           Image pixel 1197  Image pixel 1198  \
# controller category      is_reset_buffer
# SAC        LineFollowing False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#                          False                         NaN               NaN
#
#                                           Image pixel 1199  previous_step
# controller category      is_reset_buffer
# SAC        LineFollowing False                         NaN           5984
#                          False                         NaN           5985
#                          False                         NaN           5986
#                          False                         NaN              0
#                          False                         NaN              1
#                          False                         NaN              2
#                          False                         NaN           5987
#                          False                         NaN           5988
#                          False                         NaN              3
#                          False                         NaN           5989
#                          False                         NaN              4
#                          False                         NaN           5990
#                          False                         NaN              5
#                          False                         NaN           5991
#                          False                         NaN              6
#                          False                         NaN           5992
#                          False                         NaN              7
#                          False                         NaN           5993
#                          False                         NaN              8
#                          False                         NaN           5994
#                          False                         NaN              9
#                          False                         NaN           5995
#                          False                         NaN             10
#                          False                         NaN           5996
#                          False                         NaN             11
#                          False                         NaN           5997
#                          False                         NaN           5998
#
# [27 rows x 1215 columns]
